# %%
## import necessary modules

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style('darkgrid')

# %%
#import csv file

df=pd.read_csv("CustomerDefault.csv")
df.head()
# Out:
#    gender  age  ed  retire  income  creddebt   othdebt  default  marital  \
# 0       0   27  17       0      22  0.262856  2.289144        0        0
# 1       1   44  19       0      50  0.368000  4.232000        0        0
# 2       0   68  13       1      32  0.351072  6.272928        0        1
# 3       1   32  21       0      33  0.405405  1.739595        1        0
# 4       1   41  15       0      25  0.570000  1.930000        0        0
#
#    homeown
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0

# %%
df.shape
# Out:
# (2721, 10)

# %%
df.describe()
# Out:
#             gender          age           ed       retire       income  \
# count  2721.000000  2721.000000  2721.000000  2721.000000  2721.000000
# mean      0.517457    43.914002    14.761852     0.113561    54.691290
# std       0.499787    17.794929     3.270955     0.317336    60.137589
# min       0.000000    18.000000     6.000000     0.000000     9.000000
# 25%       0.000000    28.000000    12.000000     0.000000    23.000000
# 50%       1.000000    42.000000    15.000000     0.000000    37.000000
# 75%       1.000000    58.000000    17.000000     0.000000    64.000000
# max       1.000000    79.000000    23.000000     1.000000  1073.000000
#
#           creddebt      othdebt      default      marital      homeown
# count  2721.000000  2721.000000  2721.000000  2721.000000  2721.000000
# mean      2.208151     3.929531     0.429989     0.474825     0.634326
# std       4.334525     6.026252     0.495165     0.499458     0.481707
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2721 entries, 0 to 2720
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   gender    2721 non-null   int64
#  1   age       2721 non-null   int64
#  2   ed        2721 non-null   int64
#  3   retire    2721 non-null   int64
#  4   income    2721 non-null   int64
#  5   creddebt  2721 non-null   float64
#  6   othdebt   2721 non-null   float64
#  7   default   2721 non-null   int64
#  8   marital   2721 non-null   int64
#  9   homeown   2721 non-null   int64
# dtypes: float64(2), int64(8)
# memory usage: 212.7 KB

# %%
# correlation within features

plt.figure(figsize=(12,7))
corrMat=df.corr()
sns.heatmap(corrMat, annot=True)
plt.show()

# %%
df[df.columns[1:]].corr()['default'][:]
# Out:
# age        -0.466447
# ed          0.121129
# retire     -0.275774
# income      0.005645
# creddebt    0.206647
# othdebt     0.128392
# default     1.000000
# marital    -0.032029
# homeown    -0.049571
# Name: default, dtype: float64

# %%
df.head(2)
# Out:
#    gender  age  ed  retire  income  creddebt   othdebt  default  marital  \
# 0       0   27  17       0      22  0.262856  2.289144        0        0
# 1       1   44  19       0      50  0.368000  4.232000        0        0
#
#    homeown
# 0        0
# 1        1

# %% [markdown]
# # Gender

# %%
df['gender'].value_counts()
# Out:
# 1    1408
# 0    1313
# Name: gender, dtype: int64

# %%
# 0=Male, 1=Female

plt.figure(figsize=(7,5))
sns.countplot(x='gender',order=[0,1],data=df).set_title("Gender",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'Gender')

# %%
plt.figure(figsize=(7,5))
sns.countplot(x="gender",hue="default",data=df,palette='bright',order=[0,1]).set_title("No. of Customer (Default vs Non Default)",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'No. of Customer (Default vs Non Default)')

# %% [markdown]
# # Age

# %%
sns.displot(data=df, x="age",kind="hist",kde=True,palette="bright",height=5, aspect=2)

# %%
sns.displot(data=df, x="age",hue="default",kind="hist",kde=True,palette="bright",height=5, aspect=2)

# %% [markdown]
# # Years of education

# %%
sns.displot(data=df, x="ed",kind="hist",kde=True,palette="bright",height=5, aspect=2)

# %%
sns.displot(data=df, x="ed",hue="default",kind="hist",kde=True,palette="bright",height=5, aspect=2)

# %% [markdown]
# # Retire

# %%
df["retire"].value_counts()
# Out:
# 0    2412
# 1     309
# Name: retire, dtype: int64

# %%
# 0=not retired, 1=retired

plt.figure(figsize=(7,5))
sns.countplot(x='retire',order=[0,1],data=df).set_title("Retire",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'Retire')

# %%
plt.figure(figsize=(7,5))
sns.countplot(x="retire",hue="default",data=df,palette='bright',order=[0,1]).set_title("No. of Customer (Default vs Non Default)",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'No. of Customer (Default vs Non Default)')

# %% [markdown]
# # Income

# %%
sns.displot(data=df, x="income",kind="hist",kde=True,palette="bright",height=5, aspect=1)

# %%
sns.displot(data=df, x="income",hue="default",kind="hist",kde=True,palette="bright",height=5, aspect=2)

# %% [markdown]
# # Credit debt

# %%
sns.displot(data=df, x="creddebt",kind="hist",kde=True,palette="bright",height=5, aspect=1)

# %%
sns.displot(data=df, x="creddebt",hue="default",kind="hist",kde=True,palette="bright",height=5, aspect=1)

# %% [markdown]
# # other debt

# %%
sns.displot(data=df, x="othdebt",kind="kde",palette="bright",height=5, aspect=1)

# %%
sns.displot(data=df, x="othdebt",hue="default",kind="kde",palette="bright",height=5, aspect=1)

# %% [markdown]
# # Marital Status

# %%
df["marital"].value_counts()
# Out:
# 0    1429
# 1    1292
# Name: marital, dtype: int64

# %%
# 0=unmarried,1=married

plt.figure(figsize=(7,5))
sns.countplot(x='marital',order=[0,1],data=df).set_title("Marital Status",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'Marital Status')

# %%
plt.figure(figsize=(7,5))
sns.countplot(x="marital",hue="default",data=df,palette='bright',order=[0,1]).set_title("No. of Customer (Default vs Non Default",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'No. of Customer (Default vs Non Default')

# %%
df.head(2)
# Out:
#    gender  age  ed  retire  income  creddebt   othdebt  default  marital  \
# 0       0   27  17       0      22  0.262856  2.289144        0        0
# 1       1   44  19       0      50  0.368000  4.232000        0        0
#
#    homeown
# 0        0
# 1        1

# %% [markdown]
# # Homeown

# %%
df["homeown"].value_counts()
# Out:
# 1    1726
# 0     995
# Name: homeown, dtype: int64

# %%
#0=rents, 1=ownshome

plt.figure(figsize=(7,5))
sns.countplot(x='homeown',order=[0,1],data=df).set_title("HomeOwn",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'HomeOwn')

# %%
plt.figure(figsize=(7,5))
sns.countplot(x='marital',hue="default",order=[0,1],data=df).set_title("No. of Customer (Default vs Non Default",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'No. of Customer (Default vs Non Default')

# %% [markdown]
# # Default

# %%
df["default"].value_counts()
# Out:
# 0    1551
# 1    1170
# Name: default, dtype: int64

# %%
# 0= no default, 1= default
plt.figure(figsize=(7,5))
sns.countplot(x='default',order=[0,1],data=df).set_title("Default",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'Default')

# %%
# #Dividing dependent and independent variables
X = df.drop("default", axis=1)
y = df["default"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Feature Scaling

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression  

classifier= LogisticRegression(random_state=0)  
lr_model=classifier.fit(X_train, y_train)
y_pred=lr_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix

acc_score=accuracy_score(y_test, y_pred)   # Accuracy = TP+TN/TP+FP+FN+TN
p_score=precision_score(y_test,y_pred)     # Precision = TP/TP+FP
re_score=recall_score(y_test,y_pred)       # Recall = TP/TP+FN
f_score=f1_score(y_test,y_pred)            #F1 Score = 2*(Recall * Precision) / (Recall + Precision)

print(f'Accuracy score of the model is {acc_score}')
print(f'precision score of the model is {p_score}')
print(f'recall score of the model is {re_score}')
print(f'f1_score of the model is {f_score}')
# Out:
# Accuracy score of the model is 0.7826725403817915
# precision score of the model is 0.7193548387096774
# recall score of the model is 0.7852112676056338
# f1_score of the model is 0.7508417508417508

# %%
x_axis_labels = ['Not Default','Default']
y_axis_labels = ['Not Default','Default']

confusion_m=confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_m, annot=True,cmap='Greens', xticklabels=x_axis_labels, yticklabels=y_axis_labels)

plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
# Out:
# Text(34.0, 0.5, 'Actual Label')
